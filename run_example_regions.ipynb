# %%
from model_driver import driver
from iotools import read_results
import pandas as pd
import numpy as np
folder = r'/scratch/project_2000908/nousu/HIKET/SpaFHyData/ALappi'

# %%
# runs model
outputfile = driver(create_ncf=True, folder=folder, param_module="parameters_regions")
# reads results from .nc-file
#results = read_results(outputfile)
# Out:
# /projappl/project_2000908/nousu/SpaFHy_Peat_HIKET/canopygrid.py:668: RuntimeWarning: invalid value encountered in arccos
#   dl = 2.0*np.arccos(cosZEN - np.sin(LAT)*np.sin(DECL) / (np.cos(LAT)*np.cos(DECL))) / CF / 15.0  # hours
# *** Running model ***
# *** Writing results to netCDF4-file, subset 1/1 ***
# --- Running time 264.14 seconds ---
# --- Results are in file: /scratch/project_2000908/nousu/HIKET/SpaFHyData/ALappi202603101649.nc ---

# %%
results['soil_ground_water_level'].mean(dim=['i','j']).plot()
